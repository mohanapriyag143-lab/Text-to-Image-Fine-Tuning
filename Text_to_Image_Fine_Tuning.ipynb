# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanapriyag143-lab/Text-to-Image-Fine-Tuning/blob/main/Text_to_Image_Fine_Tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Connect Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q diffusers transformers accelerate peft safetensors huggingface_hub

# %%
from huggingface_hub import login

login("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")

# %%
import os

base_path = "/content/drive/MyDrive/Text_to_Image_Project"

for folder in os.listdir(base_path):
    print(repr(folder))
# Out:
# ' dataset'
# 'outputs'
# 'notebook'
# 'screenshots'
# 'lora_model'

# %%
import os

base_path = "/content/drive/MyDrive/Text_to_Image_Project"
dataset_path = os.path.join(base_path, " dataset") # Corrected to include the leading space

for file in os.listdir(dataset_path):
    if file.endswith(".png"):
        txt_name = file.replace(".png", ".txt")
        txt_path = os.path.join(dataset_path, txt_name)

        with open(txt_path, "w") as f:
            f.write("a beautiful rose flower")

print("All text files created successfully!")
# Out:
# All text files created successfully!

# %%
import os

dataset_path = "/content/drive/MyDrive/Text_to_Image_Project/ dataset" # Corrected to include the leading space
print(os.listdir(dataset_path)[:10])
# Out:
# ['rose1.png', 'rose2.png', 'rose3.png', 'rose4.png', 'rose5.png', 'rose6.png', 'rose7.png', 'rose8.png', 'rose9.png', 'rose10.png']

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "runwayml/stable-diffusion-v1-5"

pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    torch_dtype=torch.float16
).to("cuda")

print("Model loaded successfully!")
# Out:
# ...
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# CLIPTextModel LOAD REPORT from: /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]
# StableDiffusionSafetyChecker LOAD REPORT from: /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-v1-5/snapshots/451f4fe16113bff5a5d2269ed5ad43b0592e9a14/safety_checker
# Key                                               | Status     |  |
# --------------------------------------------------+------------+--+-
# vision_model.vision_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# ...

# %%
import os

# Output folder
output_path = "/content/drive/MyDrive/Text_to_Image_Project/outputs"
os.makedirs(output_path, exist_ok=True)

# Prompt
prompt = "a beautiful realistic red rose in a garden, highly detailed, 4k"

# Generate image
image = pipe(prompt).images[0]

# Save image
save_path = os.path.join(output_path, "generated_rose.png")
image.save(save_path)

print("Image saved at:", save_path)

# Show image
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Image saved at: /content/drive/MyDrive/Text_to_Image_Project/outputs/generated_rose.png
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import os

# Output folder
output_path = "/content/drive/MyDrive/Text_to_Image_Project/outputs"
os.makedirs(output_path, exist_ok=True)

# Prompt
prompt = "a beautiful white rose, realistic, highly detailed, 4k"

# Generate image
image = pipe(prompt).images[0]

# Save image
save_path = os.path.join(output_path, "generated_rose.png")
image.save(save_path)

print("Image saved at:", save_path)

# Show image
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Image saved at: /content/drive/MyDrive/Text_to_Image_Project/outputs/generated_rose.png
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import os

# Output folder
output_path = "/content/drive/MyDrive/Text_to_Image_Project/outputs"
os.makedirs(output_path, exist_ok=True)

# Prompt
prompt = "a rare blue rose flower, ultra realistic"

# Generate image
image = pipe(prompt).images[0]

# Save image
save_path = os.path.join(output_path, "generated_rose.png")
image.save(save_path)

print("Image saved at:", save_path)

# Show image
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Image saved at: /content/drive/MyDrive/Text_to_Image_Project/outputs/generated_rose.png
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import os

# Output folder
output_path = "/content/drive/MyDrive/Text_to_Image_Project/outputs"
os.makedirs(output_path, exist_ok=True)

# Prompt
prompt = "a bouquet of colorful roses, realistic, highly detailed"

# Generate image
image = pipe(prompt).images[0]

# Save image
save_path = os.path.join(output_path, "generated_rose.png")
image.save(save_path)

print("Image saved at:", save_path)

# Show image
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Image saved at: /content/drive/MyDrive/Text_to_Image_Project/outputs/generated_rose.png
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import os

# Output folder
output_path = "/content/drive/MyDrive/Text_to_Image_Project/outputs"
os.makedirs(output_path, exist_ok=True)

# Prompt
prompt = "a mysterious black rose flower, realistic, dramatic lighting"

# Generate image
image = pipe(prompt).images[0]

# Save image
save_path = os.path.join(output_path, "generated_rose.png")
image.save(save_path)

print("Image saved at:", save_path)

# Show image
image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Image saved at: /content/drive/MyDrive/Text_to_Image_Project/outputs/generated_rose.png
# <PIL.Image.Image image mode=RGB size=512x512>
